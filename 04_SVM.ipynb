# %% [markdown]
# <a href="https://colab.research.google.com/github/thatvivekhingu/Machine_learning/blob/main/04_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris=load_iris()

# %%
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df=pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# add target column in df

# %%
df['target']=iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df['flower_name']=df.target.apply(lambda X:iris.target_names[X])

# %%
df0 =df[df.target==0]
df1=df[df.target==1]
df2=df[df.target==2]

# %%
df2.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower_name
# 100       2   virginica
# 101       2   virginica
# 102       2   virginica
# 103       2   virginica
# 104       2   virginica

# %% [markdown]
# ## Draw plot

# %%
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color='green',marker='+')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='red',marker='.')
plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color='black',marker='*')
plt.xlabel('sepal length (cm)')
plt.ylabel('sepal width (cm)')
# Out:
# Text(0, 0.5, 'sepal width (cm)')

# %% [markdown]
# ## **if i want clear classification**

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(['target','flower_name'], axis='columns')

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X_train,X_test,y_train,y_test=train_test_split(X,df.target,test_size=0.2)

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.predict(X_test)
# Out:
# array([1, 0, 1, 0, 0, 0, 2, 1, 1, 1, 0, 2, 2, 1, 1, 0, 0, 1, 0, 2, 0, 0,
#        0, 2, 1, 2, 1, 2, 1, 1])
